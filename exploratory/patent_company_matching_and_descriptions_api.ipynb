# %% [markdown]
# # Combining patent data with KCMO Business Licenses

# %%
## import Python packages ##
import time # to convert time as needed and report how long some functions take

# interacting with websites and web-APIs
import requests # easy way to interact with web sites and services
import json # read/write JavaScript Object Notation (JSON)
from bs4 import BeautifulSoup

# data manipulation
import pandas as pd # easy data manipulation
from pandas import DataFrame
# import geopandas as gpd # geographic data manipulation
# from geopandas.tools import sjoin, overlay # spatial join and overlay functions
# from shapely.geometry import Point, LineString # to create lines from a list of points

# visualization
import matplotlib as mplib
import matplotlib.pyplot as plt # visualization package

import math
import os
import numpy as np 

# so images get plotted in the notebook
# %matplotlib inline

import time

# %% [markdown]
# ## Merge patent data and KCMO business licenses on Business Name

# %%
patent_data = pd.read_csv('../../data/USPTO/patent_data.csv')
kcmo = pd.read_csv('../../data/KCMO/BusinessLicense2013_2018NYU_01222018.csv')
# Out:
# /Users/nj995/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,1,2,3,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
kcmo
# Out:
#                                      fstrBusinessActivity  \
# 0                                       Consumer Lending
# 1                                       Consumer Lending
# 2                                 Temporary Help Services
# 3                                 Temporary Help Services
# 4                                 Temporary Help Services
# 5                                 Temporary Help Services
# 6                                 Temporary Help Services
# 7                                       Limousine Service
# 8                                       Limousine Service
# 9                     Administration of Housing Programs
# 10                    Administration of Housing Programs
# 11      Commercial and Institutional Building Construc...
# 12      Commercial and Institutional Building Construc...
# 13      Commercial and Institutional Building Construc...
# 14      Commercial and Institutional Building Construc...
# 15      Commercial and Institutional Building Construc...
# 16                         Marketing Consulting Services
# 17                         Marketing Consulting Services
# 18                         Marketing Consulting Services
# 19                                      Limousine Service
# 20                                Sports Teams and Clubs
# 21                                Sports Teams and Clubs
# 22                                Sports Teams and Clubs
# 23                                Sports Teams and Clubs
# 24                                Sports Teams and Clubs
# 25                                         Beauty Salons
# 26      All Other Miscellaneous Store Retailers (excep...
# 27                                      Used Car Dealers
# 28                                      Used Car Dealers
# 29                 Lessors of Other Real Estate Property
# ...                                                   ...
# 104332  Commercial and Institutional Building Construc...
# 104333  Commercial and Institutional Building Construc...
# 104334  Commercial and Institutional Building Construc...
# 104335  Commercial and Institutional Building Construc...
# 104336  Commercial and Institutional Building Construc...
# 104337                                  Limousine Service
# 104338                                  Limousine Service
# 104339                                  Limousine Service
# 104340                                  Limousine Service
# 104341         General Line Grocery Merchant Wholesalers
# 104342         General Line Grocery Merchant Wholesalers
# 104343         General Line Grocery Merchant Wholesalers
# 104344         General Line Grocery Merchant Wholesalers
# 104345         General Line Grocery Merchant Wholesalers
# 104346  Supermarkets and Other Grocery (except Conveni...
# 104347  Supermarkets and Other Grocery (except Conveni...
# 104348  Supermarkets and Other Grocery (except Conveni...
# 104349  Supermarkets and Other Grocery (except Conveni...
# 104350  All Other Miscellaneous Store Retailers (excep...
# 104351  All Other Miscellaneous Store Retailers (excep...
# 104352  All Other Miscellaneous Store Retailers (excep...
# 104353  All Other Miscellaneous Store Retailers (excep...
# 104354  Commercial and Institutional Building Construc...
# 104352  HOG LIFE ACCESSORIES & WHEELS LLC         12/31/16
# 104353  HOG LIFE ACCESSORIES & WHEELS LLC         12/31/17
# 104354                                NaN         12/31/13
# 104355                                NaN         12/31/14
# 104356                BARBER SHOP RECORDS         12/31/15
# 104357                BARBER SHOP RECORDS         12/31/15
# 104358                BARBER SHOP RECORDS         12/31/13
# 104359                                NaN         12/31/16
# 104360                                NaN         12/31/17
# 104361                                NaN         12/31/18
#
# [104362 rows x 5 columns]

# %% [markdown]
# ___Drop duplicate data for KMCO Business Licenses___

# %%
kcmo = kcmo.drop_duplicates()
kcmo.describe(include = 'all')
# Out:
#                                      fstrBusinessActivity  \
# count                                               99345
# unique                                                626
# top     Commercial and Institutional Building Construc...
# freq                                                19273
#
#                                               fstrAddress  \
# count                                               99345
# unique                                              30654
# top     2405 GRAND BLVD STE 1020 KANSAS CITY MO 64108-...
# freq                                                  139
#
#                       fstrlegalName                       fstrDBAName  \
# count                         99345                             33719
# unique                        33593                             10351
# top     REDBOX AUTOMATED RETAIL LLC  CASH AMERICA PAWN OF KANSAS CITY
# freq                            313                                70
#
#        fdtmfilingPeriod
# count             99345
# unique                6
# top            12/31/17
# freq              23873

# %% [markdown]
# ___ Drop patents prior to 1995, keep only utilities patents?___

# %%
patent_data = patent_data[pd.DatetimeIndex((pd.to_datetime(patent_data['date'], errors = 'coerce'))).year >= 2003]
patent_data = patent_data[patent_data['patent_id'].str[:1].str.isnumeric()]
patent_data.describe(include = 'all')
# Out:
#                    id patent_id     type    number  country        date  \
# count         2839964   2839964  2839964   2839964  2839964     2839964
# unique        2735542   2740804       12   2735564        1        5251
# top     2014/14553554   9375242       12  14114995       US  2013-03-15
# freq               15        15   657111        15  2839964        8449
#
#                              assignee_id name_first name_last  \
# count                            2606010      19122     19122
# unique                            168511       8679      8672
# top     29a03fd21a4c9b1420a55ecba2105eae    Michael       Lee
# freq                               67147        148       261
#
#                                        organization
# count                                       2563263
# unique                                       153413
# top     International Business Machines Corporation
# freq                                          67147

# %%
patent_data['flag'] = patent_data['patent_id'].str[:1].str.isnumeric()

# %% [markdown]
# ___ RegEx the business names for matching ___

# %%
patent_data['organization_clean'] = patent_data['organization'].str.upper()
kcmo['business_name_clean'] = kcmo['fstrlegalName'].str.upper()

# remove .
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('\.', '')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('\.', '')


# remove .
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('\,', '')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('\,', '')


# replace ' by \s
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('\'', ' ')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('\'', ' ')

# replace - by \s
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('-', ' ')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('-', ' ')

# Replace & by \s&\s
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'\s?&\s?', ' & ')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'\s?&\s?', ' & ')

# replace Company by CO
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('COMPANY', 'CO')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('COMPANY', 'CO')

# replace National Association by NA
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace('NATIONAL ASSOCIATION', 'NA')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace('NATIONAL ASSOCIATION', 'NA')

# replace N A by NA
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'\bN\sA\b', 'NA')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'\bN\sA\b', 'NA')

# replace U S A by USA
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'\bU\sS\sA\b', 'USA')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'\bU\sS\sA\b', 'USA')

# replace U S by US
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'\bU\sS\b', 'US')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'\bU\sS\b', 'US')


# When THE is last word, move to front
# TEMP: Remove all THE
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'^THE\b', '')
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'\bTHE$', '')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'^THE\b', '')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'\bTHE$', '')

#More radical: remove all special characters:
patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'[^A-Z\s0-9\&]', '')
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'[^A-Z\s0-9\&]', '')

#Most radical: remove all non-alpha characters
#patent_data['organization_clean'] = patent_data['organization_clean'].str.replace(r'[^A-Z]', '')
#kcmo['business_name_clean'] = kcmo['business_name_clean'].str.replace(r'[^A-Z]', '')

# Clean
patent_data['organization_clean'] = patent_data['organization_clean'].str.strip()
kcmo['business_name_clean'] = kcmo['business_name_clean'].str.strip()
# Out:
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/nj995/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#string = "THE"
#kcmo[kcmo['Business Name'].str.contains(string)]
#patent_data[patent_data['organization'].str.contains(string)]

# %%
patent_data['organization_clean'] = patent_data['organization_clean'].fillna('')
patent_data[patent_data['organization_clean'].str.contains('HUSSEY SEATING')]
# Out:
#                     id patent_id type    number country        date  \
# 4534029  2009/12397059   8528971   12  12397059      US  2009-03-03
# 6041458  2015/14627647   9326611   14  14627647      US  2015-02-20
#
#                               assignee_id name_first name_last  \
# 4534029  ac87d80dce24c30004bd6cb822925438        NaN       NaN
# 6041458  ac87d80dce24c30004bd6cb822925438        NaN       NaN
#
#                    organization  flag organization_clean
# 4534029  Hussey Seating Company  True  HUSSEY SEATING CO
# 6041458  Hussey Seating Company  True  HUSSEY SEATING CO

# %% [markdown]
# ___ Merge datasets ___

# %%
kcmo_patents = pd.merge(kcmo, patent_data, how = 'left'
                          , left_on = 'business_name_clean'
                          , right_on = 'organization_clean')

# %%
kcmo_patents.describe(include = 'all')
# Out:
#                                 fstrBusinessActivity  \
# count                                         702398
# unique                                           626
# top     Consumer Electronics Repair and Maintenance
# freq                                          130162
#
#                                    fstrAddress          fstrlegalName  \
# count                                   702398                 702398
# unique                                   30654                  33593
# top     1  MICROSOFT WAY REDMOND WA 98052-8300  MICROSOFT CORPORATION
# freq                                    100395                 100395
#
#        fstrDBAName fdtmfilingPeriod    business_name_clean             id  \
# count        77678           702398                 702398         605519
# unique       10351                6                  33589          92803
# top     SPRINT PCS         12/31/16  MICROSOFT CORPORATION  2013/14028154
# freq          7185           151310                 100395            313
#
#        patent_id    type    number country        date  \
# count     605519  605519    605519  605519      605519
# unique     92901       7     92803       1        3924
# top      8996162      11  10824781      US  2006-04-21
# freq         313  170623       313  605519        1807
#
#                              assignee_id  name_first  name_last  \
# count                             605519         0.0        0.0
# unique                               409         0.0        0.0
# top     237c2b0099548ddbfa5a37f07e0687ab         NaN        NaN
# freq                              100395         NaN        NaN
#
#                  organization    flag     organization_clean
# count                  605519  605519                 605519
# unique                    409       1                    402
# top     Microsoft Corporation    True  MICROSOFT CORPORATION
# freq                   100395  605519                 100395

# %%
test = kcmo_patents[pd.isnull(kcmo_patents['patent_id'])== False]['organization_clean'].value_counts()

# %%
test
# Out:
# MICROSOFT CORPORATION                    100395
# HONEYWELL INTERNATIONAL INC               83080
# GENERAL ELECTRIC CO                       81910
# XEROX CORPORATION                         76869
# SPRINT SPECTRUM LP                        68976
# EASTMAN KODAK CO                          16620
# GOODYEAR TIRE & RUBBER CO                 14370
# REDBOX AUTOMATED RETAIL LLC               11894
# IGT                                       11755
# ORACLE AMERICA INC                         9075
# WALGREEN CO                                7828
# NETAPP INC                                 7310
# AVAYA INC                                  5280
# PHILLIPS 66 CO                             5049
# CA INC                                     4715
# SHERWIN WILLIAMS CO                        4500
# ALCATEL LUCENT USA INC                     4472
# AIR PRODUCTS AND CHEMICALS INC             4125
# MCAFEE INC                                 3885
# NCR CORPORATION                            3760
# ECOLAB INC                                 3648
# NIELSEN CO US LLC                          3285
# SIEMENS INDUSTRY INC                       3260
# CARRIER CORPORATION                        2995
# PITNEY BOWES INC                           2975
# MOTOROLA SOLUTIONS INC                     2958
# OTIS ELEVATOR CO                           2779
# OSRAM SYLVANIA INC                         2540
# WMS GAMING INC                             2523
# CARESTREAM HEALTH INC                      2365
#                                           ...
# FINISHMASTER INC                              3
# CMFG LIFE INSURANCE CO                        3
# INTERSTATE IMPROVEMENT INC                    3
# ENCORE TECHNOLOGIES LLC                       3
# FAN ZHANG                                     2
# COLE TAYLOR BANK                              2
# ANDREWS MCMEEL PUBLISHING LLC                 2
# INTEGRATED ROADWAYS LLC                       2
# HOK GROUP INC                                 2
# FRAZIER INDUSTRIAL CO                         2
# AMPERSAND INC                                 2
# LORILLARD TOBACCO CO                          2
# R & R PACKAGING INC                           2
# HUSSEY SEATING CO                             2
# PNC BANK NA                                   2
# ATLAS CARPET MILLS INC                        2
# F & M MAFCO INC                               2
# PURE TECHNOLOGIES US INC                      2
# CHR HANSEN INC                                2
# STEEL VENTURES LLC                            2
# ENERCON SERVICES INC                          2
# ALTRIA SALES & DISTRIBUTION INC               1
# ACCIDENT FUND INSURANCE CO OF AMERICA         1
# MONTANA SILVERSMITHS INC                      1
# DEREK PORTER STUDIO INC                       1
# SELECTIVE SITE CONSULTANTS INC                1
# MINNESOTA PUBLIC RADIO                        1
# CARDFREE INC                                  1
# AON BENFIELD INC                              1
# MT CARMEL STABILIZATION GROUP INC             1
# Name: organization_clean, Length: 402, dtype: int64

# %% [markdown]
# ## API for Patent Descriptions

# %% [markdown]
# ___ Generate list of relevant patents___

# %%
patents = kcmo_patents[kcmo_patents['patent_id'].isnull()==False]['patent_id'].drop_duplicates().tolist()
print(len(patents))

# %%
# patents = patents[:500]

# %% [markdown]
# ___ Query PatentsView API (one patent at a time)___

# %%
# df = pd.DataFrame("", index=np.arange(0), columns=['patent_abstract', 'patent_number', 'patent_title'])

# start_time = time.time()
# for patent in patents:
#     base_url = 'http://www.patentsview.org/api/patents/query?'
#     query = 'q={"patent_number":"'+ patent + '"}'
#     fields='&f=["patent_number", "patent_title", "patent_abstract"]'
#     sort= '' #&s=
#     options= '&o={"page":1,"per_page": 500}'
#     url = '{}{}{}{}{}'.format(base_url, query, fields, sort, options)
    
#     response = requests.get(url)
#     response = json.loads(response.text)
#     temp = DataFrame.from_dict(response['patents'])
#     df = pd.concat([df, temp])

# df = df.reset_index(drop = True)
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
# df

# %% [markdown]
# ___ Query PatentsView API (200 patents at a time)___

# %%
df = pd.DataFrame("", index=np.arange(0), columns=['patent_abstract', 'patent_number', 'patent_title'])
start_time = time.time()
for i in range(0, int(math.modf(len(patents)/200)[1]+1)):
    sub_patents = patents[200*i:min(200*(i+1), len(patents))]
    base_url = 'http://www.patentsview.org/api/patents/query?'
    query = 'q={"_or":[{"patent_number":"'+ sub_patents[0] + '"}'
    for j in range(1, len(sub_patents)):
        query = query + ',{"patent_number":"'+sub_patents[j]+'"}'
    query = query + ']}'
    fields='&f=["patent_number", "patent_title", "patent_abstract"]'
    sort= '' #&s=
    options= '&o={"page":1,"per_page": 500}'
    url = '{}{}{}{}{}'.format(base_url, query, fields, sort, options)
    
    response = requests.get(url)
    response = json.loads(response.text)
    temp = DataFrame.from_dict(response['patents'])
    df = pd.concat([df, temp])

df = df.reset_index(drop = True)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 281.40145778656006 seconds ---

# %%
df
# Out:
#                                          patent_abstract patent_number  \
# 0      An abrading composition and a process for abra...       6663467
# 1      A fan deck display having a case including a c...       6665965
# 2      A leak detection system for the detection and ...       6772598
# 3      A system and method for method for measuring t...       6826956
# 4      The present invention provides a method of ide...       6861229
# 5      A tool extension assembly including an extensi...       6874201
# 6      An aerosol archival product that includes an a...       6890455
# 7      A method of finishing a wood product, such as ...       6892105
# 8      A square paint container having recesses forme...       6896156
# 9      The inventive method of producing a eukaryotic...       6908762
# 10     The invention provides cells and methods of us...       6913927
# 11     A method and apparatus of for mixing a tinting...       6960012
# 12     A substrate that is treated with an archival c...       6974632
# 13     A method of preserving cellulosic material tha...       6984416
# 14     A paint color card having a substrate with a s...       6994553
# 15     A metal wire rod shopping cart wherein a reinf...       7004480
# 16     A method for selecting an architectural primer...       7014466
# 17     A pressurized paint product that includes an m...       7018557
# 18     An aerosol archival product that includes an a...       7041236
# 19     A method of verifying the color and tinting st...       7042566
# 20     A pressurized paint product that includes an a...       7064167
# 21     Apparatus and method for mixing a fluid disper...       7077560
# 22     A method of producing a finish for a selected ...       7116420
# 23     A DC to DC power converter includes synchronou...       7119524
# 24     A snow removal machine including a housing wit...       7137214
# 25     A method of enriching a solution for an adenov...       7141406
# 26     A process for color matching a metallic paint ...       7167246
# 27     A process and device is provided for coating a...       7179497
# 28     Apparatus and method for mixing a fluid disper...       7182505
# 29     Disclosed are modeling and process control tec...       7233834
# ...                                                  ...           ...
# 92671  Various embodiments include text-augmented int...       9495669
# 92672  An auger assembly designed for creation of bor...       9506295
# 92673  An auger assembly designed for creation of bor...       9512588
# 92674  An optical code scanner is presented that incl...       9519816
# 92675  A portable memory device is interfaced to a SS...       9552246
# 92676  A reversible I/O apparatus for a POS terminal ...       9575517
# 92677  Techniques for checking into a retail establis...       9576233
# 92678  Events are securely packaged and transmitted f...       9584532
# 92679  A store can stock items that have the same app...       9594843
# 92680  A transaction at a Self-Service Terminal (SST)...       9595065
# 92681  A method and apparatus are disclosed for locat...       9606576
# 92682  A system and method of connecting a computer t...       9606758
# 92683  Two endpoint devices communicate with one anot...       9628445
# 92684  A secure provisioning manifest used to authent...       9646174
# 92685  Providing security for a sensitive item is imp...       9646477
# 92686  Assistance techniques that give customers more...       9648450
# 92687  A chip-enabled card is detected within a card ...       9652640
# 92688  Various embodiments herein each include at lea...       9652752
# 92689  Various embodiments herein each include at lea...       9652762
# 92690  A method of validating resolution of a problem...       9659465
# 92691  A Basic Input/Output System (BIOS) of a device...       9672361
# 92692  Web session security techniques which protect ...       9672376
# 92693  An apparatus and method are disclosed for secu...       9691234
# 92694  Techniques for computer system recovery which ...       9697011
# 92695  A method and apparatus for identifying a media...       9704031
# 92696  An imaging system includes a camera having a f...       9710684
# 92697  A modular pod may include two or more walls, a...       9713289
# 92698  Systems and methods for deskewing a media obje...       9714149
# 92699  A point of sale terminal that performs purchas...       9715684
# 92700  Various embodiments herein each include at lea...       9720869
#
#                                             patent_title
# 0      Process and composition for abrading pre-finis...
# 1                        Ergonomic color sample fan deck
# 2                      Refrigerant leak detection system
# 3                    Differential pressure level control
# 4                   Method of identifying a gene product
# 5      Tool extension assembly with quick release loc...
# 6                             Archival spray composition
# 7      Method of producing a wood finish at a locatio...
# 8      Plastic paint container having a cube-shaped body
# 9          Method of preparing a eukaryotic viral vector
# 10     Non-adenoviral gene product-based complementin...
# 11           Method of mixing fluid in F-style container
# 12                            Archival spray composition
# 13                            Archival spray composition
# 14        Paint color card and methods of using the same
# 15     Shopping cart with advertising display frames ...
# 16           Primer selection for architectural coatings
# 17                    Magnetic aerosol paint composition
# 18                            Archival spray composition
# 19     Method of verifying color and strength propert...
# 20     Aerosol paint composition for adherence to pla...
# 21     Structure for holding either a cylindrical or ...
# 22                  Method of color matching wood stains
# 23     Control of DC/DC converters having synchronous...
# 24     Snow removal machine with system for applying ...
# 25                  Efficient purification of adenovirus
# 26              Method of color matching metallic paints
# 27                          Coated pelletized shortening
# 28     Apparatus and method for mixing a fluid disper...
# 29     Computer-aided modeling and manufacture of pro...
# ...                                                  ...
# 92671  Text-augmented interactive self-service termin...
# 92672                 Reversible displacement auger tool
# 92673                 Reversible displacement auger tool
# 92674  Method and apparatus for optimizing optical co...
# 92675  Out-of-band monitoring and managing of self-se...
# 92676                      Reversible input/output (I/O)
# 92677  Techniques for checking into a retail establis...
# 92678     Enterprise intrusion detection and remediation
# 92679  Identifying an incorrect entry at an imaging c...
# 92680                             Transaction assistance
# 92681                                   Display location
# 92682  System and method of connecting a computer to ...
# 92683                    Trusted device control messages
# 92684  Learning a new peripheral using a security pro...
# 92685         Branch device geo-fencing pairing security
# 92686                              Assistance techniques
# 92687                                       Card locking
# 92688                     Dynamic network timeout tuning
# 92689       Proximity-based transaction device selection
# 92690                      Problem resolution validation
# 92691            Self-service terminal (SST) secure boot
# 92692                    Web session security techniques
# 92693                                  Secure collection
# 92694            Techniques for computer system recovery
# 92695                               Media identification
# 92696        Multiple view single camera imaging scanner
# 92697                                        Modular pod
# 92698                                       Media deskew
# 92699  Method and apparatus for detecting misidentifi...
# 92700  Coupled device deployment location classification
#
# [92701 rows x 3 columns]

# %% [markdown]
# #############################
# #############################
# #############################

# %%
import re
re.sub('<[^>]*>', '', DataFrame.from_dict(response['patents'])['patent_abstract'][596])
# Out:
# '"A system method that adapts wireless link parameters for a wireless communication link. A measure is determined of errors signal quality occurring in communication over a wireless link. In a case that the measure of errors signal quality corresponds to more errors than a first predetermined threshold, communication changes from a first set of wireless link parameters to a second set of wireless link parameters. The second set of wireless link parameters corresponds to higher error tolerance than the first set of wireless link parameters. In a case that the measure of errors signal quality corresponds to fewer errors than a second predetermined threshold, communication changes from the first set of wireless link parameters to a third set of wireless link parameters. The third set of wireless link parameters corresponds to lower error tolerance than the first set of wireless link parameters. Preferably, the measure of errors signal quality is determined by monitoring a number of NACK messages and a number of ACK messages that occur. It is determined that the measure of errors signal quality corresponds to more errors than the first predetermined threshold when more than a predetermined number of NACK messages occur in succession. It is determined that the measure of errors signal quality corresponds to fewer errors than the second predetermined threshold when more than a predetermined number of ACK messages occur in succession."'
