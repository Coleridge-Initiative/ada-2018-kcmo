# %% [markdown]
# # QWI data

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
sa = pd.read_csv('/Users/nj995/Downloads/qwi_mo_sa_f_gm_ns_oslp_u.csv')
rh = pd.read_csv('/Users/nj995/Downloads/qwi_mo_rh_f_gm_ns_oslp_u.csv')
se = pd.read_csv('/Users/nj995/Downloads/qwi_mo_se_f_gm_ns_oslp_u.csv')

# gw = pd.read_csv('/Users/nj995/Downloads/qwi_mo_sa_f_gw_ns_oslp_u.csv')
#

# %%
sa.describe(include = 'all').round(2)
# Out:
#        periodicity seasonadj geo_level   geography ind_level industry  \
# count      1497744   1497744   1497744  1497744.00   1497744  1497744
# unique           1         1         2         NaN         2       21
# top              Q         U         M         NaN         S       72
# freq       1497744   1497744   1447281         NaN   1425654    72090
# mean           NaN       NaN       NaN  2835463.12       NaN      NaN
# std            NaN       NaN       NaN   529677.08       NaN      NaN
# min            NaN       NaN       NaN       29.00       NaN      NaN
# 25%            NaN       NaN       NaN  2922800.00       NaN      NaN
# 50%            NaN       NaN       NaN  2932180.00       NaN      NaN
# 75%            NaN       NaN       NaN  2941140.00       NaN      NaN
# max            NaN       NaN       NaN  2999999.00       NaN      NaN
#
#        ownercode         sex   agegrp     race ethnicity education    firmage  \
# ...

# %%
rh.describe(include = 'all').round(2)
# Out:
#        periodicity seasonadj geo_level   geography ind_level industry  \
# count      1164912   1164912   1164912  1164912.00   1164912  1164912
# unique           1         1         2         NaN         2       21
# top              Q         U         M         NaN         S       71
# freq       1164912   1164912   1125663         NaN   1108842    56070
# mean           NaN       NaN       NaN  2835463.12       NaN      NaN
# std            NaN       NaN       NaN   529677.13       NaN      NaN
# min            NaN       NaN       NaN       29.00       NaN      NaN
# 25%            NaN       NaN       NaN  2922800.00       NaN      NaN
# 50%            NaN       NaN       NaN  2932180.00       NaN      NaN
# 75%            NaN       NaN       NaN  2941140.00       NaN      NaN
# max            NaN       NaN       NaN  2999999.00       NaN      NaN
#
#        ownercode        sex   agegrp     race ethnicity education    firmage  \
# ...

# %%
se.describe(include = 'all').round(2)
# Out:
#        periodicity seasonadj geo_level   geography ind_level industry  \
# count       998496    998496    998496   998496.00    998496   998496
# unique           1         1         2         NaN         2       21
# top              Q         U         M         NaN         S       71
# freq        998496    998496    964854         NaN    950436    48060
# mean           NaN       NaN       NaN  2835463.12       NaN      NaN
# std            NaN       NaN       NaN   529677.17       NaN      NaN
# min            NaN       NaN       NaN       29.00       NaN      NaN
# 25%            NaN       NaN       NaN  2922800.00       NaN      NaN
# 50%            NaN       NaN       NaN  2932180.00       NaN      NaN
# 75%            NaN       NaN       NaN  2941140.00       NaN      NaN
# max            NaN       NaN       NaN  2999999.00       NaN      NaN
#
#        ownercode        sex  agegrp    race ethnicity education   firmage  \
# ...

# %%
pd.crosstab(index = sa['geography'], columns = 'count')
# Out:
# col_0      count
# geography
# 29         50463
# 2914700    50463
# 2916020    50463
# 2917860    50463
# 2922100    50463
# 2922220    50193
# 2922780    50409
# 2922800    44469
# 2925300    50463
# 2927620    50463
# 2927900    50463
# 2928140    50463
# 2928380    48168
# 2928860    48060
# 2930060    49005
# 2932180    49545
# 2932340    50463
# 2933020    49248
# 2933620    50463
# 2938740    49950
# 2939500    50463
# 2940620    50463
# 2941140    50463
# 2941180    50463
# 2942740    50463
# 2943460    49707
# 2944180    50463
# 2947660    50193
# 2948460    50463
# 2999999    50463

# %%
test = sa[(sa['geography'] == 2914700)&(sa['year']==1995)&(sa['quarter']==1)].reset_index(drop = True)
test[(test['sex']==0)&(test['agegrp']=='A00')]
#.to_csv('../test.csv')
# Out:
#     periodicity seasonadj geo_level  geography ind_level industry ownercode  \
# 0             Q         U         M    2914700         A       00       A00
# 27            Q         U         M    2914700         S       11       A00
# 54            Q         U         M    2914700         S       21       A00
# 81            Q         U         M    2914700         S       22       A00
# 108           Q         U         M    2914700         S       23       A00
# 135           Q         U         M    2914700         S    31-33       A00
# 162           Q         U         M    2914700         S       42       A00
# 189           Q         U         M    2914700         S    44-45       A00
# 216           Q         U         M    2914700         S    48-49       A00
# 243           Q         U         M    2914700         S       51       A00
# 270           Q         U         M    2914700         S       52       A00
# ...

# %%
pd.crosstab(index = test['industry'], columns = "count")
# Out:
# col_0     count
# industry
# 00           27
# 11           27
# 21           27
# 22           27
# 23           27
# 31-33        27
# 42           27
# 44-45        27
# 48-49        27
# 51           27
# 52           27
# 53           27
# 54           27
# 55           27
# 56           27
# 61           27
# 62           27
# 71           27
# 72           27
# 81           27
# 92           27

# %%
9*21*3
# Out:
# 567
