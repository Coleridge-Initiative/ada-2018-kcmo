# %%
## import Python packages ##
import time # to convert time as needed and report how long some functions take

# interacting with websites and web-APIs
import requests # easy way to interact with web sites and services
import json # read/write JavaScript Object Notation (JSON)
from bs4 import BeautifulSoup

# data manipulation
import pandas as pd # easy data manipulation
from pandas import DataFrame
# import geopandas as gpd # geographic data manipulation
# from geopandas.tools import sjoin, overlay # spatial join and overlay functions
# from shapely.geometry import Point, LineString # to create lines from a list of points

# visualization
import matplotlib as mplib
import matplotlib.pyplot as plt # visualization package

import math

# so images get plotted in the notebook
# %matplotlib inline

# %%
parameters = '{"_and":[{"_gte": {"patent_date": "2014-1-1"}},{"_lt": {"patent_date": "2014-2-25"}}]} '
fields='["patent_number", "patent_date", "patent_abstract", "patent_title"]'
sort= '[{"patent_date": "asc"}]'
options= '{"page":4,"per_page": 10000}'

# %%
base_url = 'http://www.patentsview.org/api/patents/'
url = '{}query?q={}&f={}&s={}&o={}'.format(base_url, parameters, fields, sort, options)

# %%
response = requests.get(url)
response = json.loads(response.text)

# %%
response['total_patent_count']
# Out:
# 37853

# %%
DataFrame.from_dict(response['patents'])
# Out:
#                                         patent_abstract patent_date  \
# 0     A method of determining a color transformation...  2014-02-11
# 1     According to one embodiment, a plaque region e...  2014-02-11
# 2     A pupil detection device and a pupil detection...  2014-02-11
# 3     A medical image processing apparatus includes ...  2014-02-11
# 4     A method and system for retrospective image co...  2014-02-11
# 5     A color flow gain adjustment method and device...  2014-02-11
# 6     Several related inventions for estimating scat...  2014-02-11
# 7     A method for canceling the impact of the physi...  2014-02-11
# 8     Embodiments herein provide methods for noninva...  2014-02-11
# 9     A paper sheet management apparatus includes: a...  2014-02-11
# 10    In accordance with an embodiment, a pattern in...  2014-02-11
# 11    A system for background image subtraction incl...  2014-02-11
# 12    An image processing apparatus includes a proje...  2014-02-11
# 13    A method for assessing events detected by a su...  2014-02-11
# 14    Systems, methods, and apparatus for sampling i...  2014-02-11
# 15    An image processing system, comprising a compu...  2014-02-11
# 16    An image processing apparatus includes a histo...  2014-02-11
# 17    The method comprises, for each cross-section i...  2014-02-11
# 18    The present invention relates to an image proc...  2014-02-11
# 19    Methods and systems of the present embodiment ...  2014-02-11
# 20    Disclosed herein, among other things, are meth...  2014-02-11
# 21    Various systems and methods are described for ...  2014-02-11
# 22    A computer-readable storage medium has stored ...  2014-02-11
# 23    A method of detecting a face in an image inclu...  2014-02-11
# 24    An apparatus and method for detecting foam on ...  2014-02-11
# 25    Methods and systems for generating saliency mo...  2014-02-11
# 26    Apparatus, systems, and methods integrating sp...  2014-02-11
# 27    A feature calculator calculates the number of ...  2014-02-11
# 28    An apparatus is provided that includes a plura...  2014-02-11
# 29    Example methods and apparatus for auditing sig...  2014-02-11
# ...                                                 ...         ...
# 7823                                               None  2014-02-18
# 7824                                               None  2014-02-18
# 7825                                               None  2014-02-18
# 7826                                               None  2014-02-18
# 7827                                               None  2014-02-18
# 7828                                               None  2014-02-18
# 7829                                               None  2014-02-18
# 7830                                               None  2014-02-18
# 7831                                               None  2014-02-18
# 7832                                               None  2014-02-18
# 7833                                               None  2014-02-18
# 7834                                               None  2014-02-18
# 7835                                               None  2014-02-18
# 7836                                               None  2014-02-18
# 7837  A new garden rose plant of the Climbing class ...  2014-02-18
# 7838  A new garden rose plant of the Climbing class ...  2014-02-18
# 7839  Description and specifications of a new and di...  2014-02-18
# 7840  A new and distinct grapevine variety is charac...  2014-02-18
# 7841  A new and distinct cultivar of <i>Viburnum </i...  2014-02-18
# 7842  A new and distinct cultivar of Lilac plant nam...  2014-02-18
# 7843  A new and distinct cultivar of <i>Kalanchoe </...  2014-02-18
# 7844  A new and distinct cultivar of <i>Kalanchoe </...  2014-02-18
# 7845  A new and distinct cultivar of <i>Kalanchoe </...  2014-02-18
# 7846  A new and distinct cultivar of <i>Haworthia </...  2014-02-18
# 7847  A new and distinct cultivar of <i>Calathea ros...  2014-02-18
# 7848  A photo-sensor image resolution adjustment app...  2014-02-18
# 7849  An efficient X-ray radiographic method for rec...  2014-02-18
# 7850  A method of allocating radio resources in a wi...  2014-02-18
# 7851                        A compound of the structure  2014-02-18
# 7852                                               None  2014-02-18
#
#      patent_number                                       patent_title
# 0          8649581           Colour management for biological samples
# 1          8649582  Plaque region extracting method and apparatus ...
# 2          8649583  Pupil detection device and pupil detection method
# 3          8649584  Medical image processing apparatus and medical...
# 4          8649585  Method and system for retrospective image comb...
# 5          8649586       Color flow gain adjustment method and device
# 6          8649587  Methods, systems, and computer-program product...
# 7          8649588  Method for canceling impact of physical proper...
# 8          8649589            Noninvasive assessment of keratinocytes
# 9          8649590  Paper sheet management apparatus, paper sheet ...
# 10         8649591  Pattern inspection apparatus and pattern inspe...
# 11         8649592   System for background subtraction with 3D camera
# 12         8649593  Image processing apparatus, image processing m...
# 13         8649594  Active and adaptive intelligent video surveill...
# 14         8649595                 Subpixel-based image down-sampling
# 15         8649596  System and process for color-balancing a serie...
# 16         8649597  Image processing apparatus and control method ...
# 17         8649598  Method for determining a three-dimensional rep...
# 18         8649599  Image processing apparatus, image processing m...
# 19         8649600  System and method for segmenting text lines in...
# 20         8649601  Method and apparatus for verifying answer docu...
# 21         8649602             Systems and methods for tagging photos
# 22         8649603  Computer-readable storage medium having inform...
# 23         8649604  Face searching and detection in a digital imag...
# 24         8649605  Method and apparatus for detecting foam on a l...
# 25         8649606  Methods and systems for generating saliency mo...
# 26         8649607  Spectral ratio contrast for edge detection in ...
# 27         8649608  Feature value extracting device, object identi...
# 28         8649609  Field programmable gate array apparatus, metho...
# 29         8649610         Methods and apparatus for auditing signage
# ...            ...                                                ...
# 7823       D699902                  Animal medical alert vest-seizure
# 7824       D699903                                     Comb apparatus
# 7825       D699904                                    Dishwasher door
# 7826       D699905                          Frame for washing machine
# 7827       D699906                                      Clothes dryer
# 7828       D699907                                    Washing machine
# 7829       D699908                              Big dot pattern wiper
# 7830       D699909                                      Cleaning tool
# 7831       D699910       Dust-proof mechanism for a positioning cover
# 7832       D699911                               Forklift lever cover
# 7833       D699912                                       Loading rack
# 7834       D699913                                       Loading rack
# 7835       D699914                                                Urn
# 7836       D699915              All weather mailbox opening indicator
# 7837       PP24247  Climbing rose plant named &#x2018;Poulcy021&#x...
# 7838       PP24248  Climbing rose plant named &#x2018;Poulcy022&#x...
# 7839       PP24249      Blackberry plant named &#x2018;APF-77&#x2019;
# 7840       PP24250  Grapevine plant named &#x2018;Sugrafortytwo&#x...
# 7841       PP24251  <i>Viburnum </i>plant named &#x2018;Spiro&#x2019;
# 7842       PP24252     Lilac plant named &#x2018;Pink Perfume&#x2019;
# 7843       PP24253  <i>Kalanchoe </i>plant named &#x2018;Katapifa&...
# 7844       PP24254  <i>Kalanchoe </i>plant named &#x2018;Fikalcerr...
# 7845       PP24255  <i>Kalanchoe </i>plant named &#x2018;Katarore&...
# 7846       PP24256  <i>Haworthia </i>plant named &#x2018;African A...
# 7847       PP24257                                         Variety of
# 7848       RE44765  Column averaging/row binning circuit for image...
# 7849       RE44766  X-ray radiographic method of recognition of ma...
# 7850       RE44767  Method of allocating radio resources in a wire...
# 7851       RE44768                            Rapamycin hydroxyesters
# 7852       RE44769                                        Dispersants
#
# [7853 rows x 4 columns]

# %%
import re
re.sub('<[^>]*>', '', DataFrame.from_dict(response['patents'])['patent_abstract'][596])
# Out:
# '"A system method that adapts wireless link parameters for a wireless communication link. A measure is determined of errors signal quality occurring in communication over a wireless link. In a case that the measure of errors signal quality corresponds to more errors than a first predetermined threshold, communication changes from a first set of wireless link parameters to a second set of wireless link parameters. The second set of wireless link parameters corresponds to higher error tolerance than the first set of wireless link parameters. In a case that the measure of errors signal quality corresponds to fewer errors than a second predetermined threshold, communication changes from the first set of wireless link parameters to a third set of wireless link parameters. The third set of wireless link parameters corresponds to lower error tolerance than the first set of wireless link parameters. Preferably, the measure of errors signal quality is determined by monitoring a number of NACK messages and a number of ACK messages that occur. It is determined that the measure of errors signal quality corresponds to more errors than the first predetermined threshold when more than a predetermined number of NACK messages occur in succession. It is determined that the measure of errors signal quality corresponds to fewer errors than the second predetermined threshold when more than a predetermined number of ACK messages occur in succession."'
